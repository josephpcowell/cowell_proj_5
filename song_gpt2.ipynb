# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from transformers import AutoTokenizer, GPT2Tokenizer
import gpt_2_simple as gpt2

import os
# Out:
# Neither PyTorch nor TensorFlow >= 2.0 have been found.Models won't be available and only tokenizers, configurationand file/data utilities can be used.

# %%
# !pip install gpt-2-simple
# Out:
# Collecting gpt-2-simple
#   Downloading gpt_2_simple-0.7.1.tar.gz (24 kB)
# Requirement already satisfied: regex in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from gpt-2-simple) (2020.10.15)
# Requirement already satisfied: requests in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from gpt-2-simple) (2.21.0)
# Requirement already satisfied: tqdm in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from gpt-2-simple) (4.51.0)
# Requirement already satisfied: numpy in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from gpt-2-simple) (1.19.2)
# Collecting toposort
#   Downloading toposort-1.5-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from requests->gpt-2-simple) (2.8)
# Collecting urllib3<1.25,>=1.21.1
#   Using cached urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from requests->gpt-2-simple) (2020.11.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from requests->gpt-2-simple) (3.0.4)
# Building wheels for collected packages: gpt-2-simple
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7.1-py3-none-any.whl size=23580 sha256=7d8efc84cb9414009e83de224b4d2d06e3f1bbda7a81e8089fc1ace6867a745a
#   Stored in directory: /Users/joecowell/Library/Caches/pip/wheels/60/c5/ff/c3c4675c593b7d3b0cc05d685a6273bef62bc8814be2f06310
# Successfully built gpt-2-simple
# Installing collected packages: toposort, gpt-2-simple, urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# lyricsgenius 2.0.1 requires beautifulsoup4==4.6.0, but you'll have beautifulsoup4 4.9.3 which is incompatible.
# botocore 1.19.3 requires urllib3<1.26,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# Successfully installed gpt-2-simple-0.7.1 toposort-1.5 urllib3-1.24.3

# %%
# !pip install tensorflow==1.14.0
# Out:
# Collecting tensorflow==1.14.0
#   Downloading tensorflow-1.14.0-cp37-cp37m-macosx_10_11_x86_64.whl (105.8 MB)
#      |████████████████████████████████| 105.8 MB 11.0 MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.2.0)
# Requirement already satisfied: six>=1.10.0 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.15.0)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488 kB)
#      |████████████████████████████████| 488 kB 4.0 MB/s
# Requirement already satisfied: wheel>=0.26 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.35.1)
# Requirement already satisfied: gast>=0.2.0 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.3.3)
# Requirement already satisfied: wrapt>=1.11.1 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.11.2)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.8.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.33.2)
# Requirement already satisfied: protobuf>=3.6.1 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (3.13.0)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 4.0 MB/s
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.19.2)
# Requirement already satisfied: absl-py>=0.7.0 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.11.0)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading tensorboard-1.14.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 8.6 MB/s
# Requirement already satisfied: setuptools in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow==1.14.0) (50.3.1.post20201107)
# Requirement already satisfied: h5py in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from keras-applications>=1.0.6->tensorflow==1.14.0) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (3.3.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (3.4.0)
# Installing collected packages: tensorflow-estimator, keras-applications, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.4.0
#     Uninstalling tensorboard-2.4.0:
#       Successfully uninstalled tensorboard-2.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.3.1
#     Uninstalling tensorflow-2.3.1:
#       Successfully uninstalled tensorflow-2.3.1
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-3.5.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.9 MB/s
# Collecting tokenizers==0.9.3
#   Downloading tokenizers-0.9.3-cp37-cp37m-macosx_10_11_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 7.9 MB/s
# Requirement already satisfied: tqdm>=4.27 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from transformers) (4.51.0)
# Requirement already satisfied: requests in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from transformers) (2.21.0)
# Requirement already satisfied: protobuf in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from transformers) (3.13.0)
# Requirement already satisfied: numpy in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from transformers) (1.19.2)
# Collecting sacremoses
#   Downloading sacremoses-0.0.43.tar.gz (883 kB)
#      |████████████████████████████████| 883 kB 3.9 MB/s
# Collecting sentencepiece==0.1.91
#   Downloading sentencepiece-0.1.91-cp37-cp37m-macosx_10_6_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 6.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from transformers) (2020.10.15)
# Requirement already satisfied: filelock in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: packaging in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from transformers) (20.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from requests->transformers) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from requests->transformers) (2020.11.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six>=1.9 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from protobuf->transformers) (1.15.0)
# Requirement already satisfied: setuptools in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from protobuf->transformers) (50.3.1.post20201107)
# Requirement already satisfied: click in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from sacremoses->transformers) (0.17.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages (from packaging->transformers) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=893259 sha256=83e6e739e4c56a22b1ac524142bd6860b5ff75d6aa50f8ea5474e0daeca07e94
#   Stored in directory: /Users/joecowell/Library/Caches/pip/wheels/69/09/d1/bf058f7d6fa0ecba2ce7c66be3b8d012beb4bf61a6e0c101c0
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, sentencepiece, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.91 tokenizers-0.9.3 transformers-3.5.1

# %%
model_name = "124M"
if not os.path.isdir(os.path.join("models", model_name)):
    print(f"Downloading {model_name} model...")
    gpt2.download_gpt2(model_name=model_name)

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2', 
                                          bos_token='<|startoftext|>', 
                                          eos_token='<|endoftext|>', 
                                          pad_token='<|pad|>')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.

# %%
file_name = 'Data/BeatlesDF.txt'

sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              model_name=model_name,
              steps=450)   # steps is max number of training steps
# Out:
# WARNING:tensorflow:From /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages/gpt_2_simple/src/sample.py:17: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# WARNING:tensorflow:From /Users/joecowell/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  4.17it/s]
# dataset has 45763 tokens
# Training...
# [1 | 35.02] loss=2.38 avg=2.38
# [2 | 62.21] loss=1.99 avg=2.18
# [3 | 91.80] loss=2.16 avg=2.18
# [4 | 118.43] loss=2.47 avg=2.25
# [5 | 146.16] loss=1.90 avg=2.18
# [6 | 173.68] loss=2.51 avg=2.23
# [7 | 200.52] loss=2.45 avg=2.27
# [8 | 226.40] loss=2.55 avg=2.30
# [9 | 253.31] loss=2.05 avg=2.27
# [10 | 279.77] loss=1.89 avg=2.23
# [11 | 306.27] loss=2.03 avg=2.21
# [12 | 334.28] loss=2.19 avg=2.21
# [13 | 360.39] loss=1.89 avg=2.19
# [14 | 383.91] loss=2.01 avg=2.17
# [15 | 407.42] loss=2.21 avg=2.17
# [16 | 430.96] loss=1.89 avg=2.16
# [17 | 454.32] loss=1.98 avg=2.14
# [18 | 477.64] loss=1.57 avg=2.11
# [19 | 501.08] loss=1.85 avg=2.09
# [20 | 524.44] loss=1.62 avg=2.07
# [21 | 549.91] loss=1.69 avg=2.05
# [22 | 576.40] loss=1.90 avg=2.04
# [23 | 603.90] loss=1.80 avg=2.03
# [24 | 631.12] loss=1.75 avg=2.02
# [25 | 657.07] loss=1.72 avg=2.00
# [26 | 683.86] loss=1.79 avg=1.99
# [27 | 710.64] loss=1.69 avg=1.98
# [28 | 737.72] loss=1.59 avg=1.97
# [29 | 763.97] loss=1.76 avg=1.96
# [30 | 790.44] loss=1.73 avg=1.95
# [31 | 816.28] loss=2.01 avg=1.95
# [32 | 843.47] loss=1.75 avg=1.94
# [33 | 870.57] loss=1.39 avg=1.92
# [34 | 898.03] loss=1.31 avg=1.90
# [35 | 924.95] loss=1.29 avg=1.88
# [36 | 951.50] loss=1.57 avg=1.87
# [37 | 978.86] loss=1.75 avg=1.87
# [38 | 1005.86] loss=1.54 avg=1.86
# [39 | 1032.35] loss=1.52 avg=1.85
# [40 | 1058.51] loss=1.66 avg=1.84
# [41 | 1085.26] loss=1.30 avg=1.83
# [42 | 1112.58] loss=1.51 avg=1.82
# [43 | 1140.57] loss=1.64 avg=1.81
# [44 | 1168.52] loss=1.26 avg=1.80
# [45 | 1193.62] loss=1.27 avg=1.78
# [46 | 1218.60] loss=1.48 avg=1.77
# [47 | 1244.36] loss=1.37 avg=1.76
# [48 | 1268.95] loss=1.24 avg=1.75
# [49 | 1293.80] loss=1.19 avg=1.73
# [50 | 1318.32] loss=1.00 avg=1.72
# [51 | 1343.15] loss=1.12 avg=1.70
# [52 | 1370.14] loss=1.57 avg=1.70
# [53 | 1398.98] loss=1.23 avg=1.69
# [54 | 1429.25] loss=1.16 avg=1.67
# [55 | 1458.24] loss=1.61 avg=1.67
# [56 | 1486.76] loss=1.22 avg=1.66
# [57 | 1515.19] loss=1.30 avg=1.65
# [58 | 1543.87] loss=1.42 avg=1.65
# [59 | 1573.09] loss=1.46 avg=1.64
# [60 | 1605.27] loss=0.91 avg=1.63
# [61 | 1636.57] loss=1.14 avg=1.62
# [62 | 1669.65] loss=1.05 avg=1.61
# [63 | 1703.86] loss=0.98 avg=1.59
# [64 | 1738.05] loss=0.91 avg=1.58
# [65 | 1773.63] loss=0.85 avg=1.56
# [66 | 1809.33] loss=1.11 avg=1.55
# [67 | 1844.13] loss=0.98 avg=1.54
# [68 | 1880.28] loss=1.05 avg=1.53
# [69 | 1914.99] loss=0.83 avg=1.52
# [70 | 1951.12] loss=0.94 avg=1.51
# [71 | 1986.05] loss=0.88 avg=1.49
# [72 | 2016.71] loss=1.21 avg=1.49
# [73 | 2045.90] loss=0.89 avg=1.48
# [74 | 2073.98] loss=0.93 avg=1.47
# [75 | 2102.69] loss=0.82 avg=1.45
# [76 | 2130.83] loss=1.03 avg=1.45
# [77 | 2158.56] loss=0.81 avg=1.43
# [78 | 2187.05] loss=1.02 avg=1.43
# [79 | 2213.13] loss=0.51 avg=1.41
# [80 | 2236.82] loss=0.75 avg=1.40
# [81 | 2264.91] loss=0.75 avg=1.39
# [82 | 2290.26] loss=0.80 avg=1.38
# [83 | 2315.88] loss=0.63 avg=1.36
# [84 | 2341.14] loss=0.70 avg=1.35
# [85 | 2365.77] loss=0.73 avg=1.34
# [86 | 2389.60] loss=0.58 avg=1.33
# [87 | 2413.36] loss=0.60 avg=1.31
# [88 | 2437.10] loss=0.61 avg=1.30
# [89 | 2460.88] loss=0.47 avg=1.29
# [90 | 2485.48] loss=0.79 avg=1.28
# [91 | 2510.65] loss=0.53 avg=1.27
# [92 | 2536.10] loss=0.57 avg=1.26
# [93 | 2563.33] loss=0.63 avg=1.25
# [94 | 2588.83] loss=0.43 avg=1.23
# [95 | 2616.45] loss=0.42 avg=1.22
# [96 | 2645.49] loss=0.66 avg=1.21
# [97 | 2674.70] loss=0.34 avg=1.20
# [98 | 2705.34] loss=0.55 avg=1.19
# [99 | 2738.34] loss=0.43 avg=1.17
# [100 | 2769.97] loss=0.41 avg=1.16
# ======== SAMPLE 1 ========
#  me to-morrow morning Love you so much And you're making me cry I have heard that you say the only words that I can say are 'til tomorrow And you're making me cry I have heard this before When I struggled all my life to get by There's nothing that can do me no pain Tell me why You've got me running around (Help) And all my troubles are being addressed (Bye) Your kindness is showing me all The only words that I can hear are 'til tomorrow And you're making me cry "
# "The Beatles" "The Beatles (The White Album)" 1968-11-22 " Well, I was thinking of a good time, yeah Well, you know I was thinking of a good time, yeah Listen I said, ""We'll have a good time"" Well, you know I was thinking of a good time, yeah Listen Just a thought... It's a long, long time Don't want to give away my girl But she loves you so much, she might not be aware She knows that she's only got one thing left to lose Don't want to give away my girl But she loves you so much, she might not be aware She knows that she's only got one thing left to lose Don't want to give away my girl But she loves you so much, she might not be aware"
# "The Beatles" "The Beatles (The White Album)" 1968-11-22 " Michelle, ma belle I don't wanna belle But I wanna say thank you to you, it really means the world To see you smile and tell me that you mean so much To know that you mean so much to me It's such a long, long, time You haven't changed a peep, oh girl But your lips are moving me So many tears fell on my eye Two tears I would have thought far less Michelle, ji mi la As she moves her hand up my gown I think I understand But she'll leave me no other solution Oh, ma belle It's such a long, long I'd love to belle But she says you mean so much To know that you mean so much To know that you mean so much to me It's such a long, long, time You haven't changed a peep, oh girl But your lips are moving me So many tears fell on my eye Two tears I would have thought far less You don't look at me, you don't talk At all You just see me and think you know me Oh, ma belle It's such a long, long, time You haven't changed a peep, oh girl You say you mean so much To see you smile and to tell me that you mean so much to me That's it, you mean so much To know that you mean so much to me Michelle, ma belle It's such a long, long, time You haven't changed a peep, oh girl But your lips are moving me So many tears fell on my eye Two tears I would have thought far less"
# "The Beatles" "The Beatles (The White Album)" 1968-11-22 " I thought you said you would if I noticed You say your word but I still have to go I thought you would say you would win if I could See you, I guess I'm through Now I've got a feeling I'll get back to you Wait till I tell you I'll be glad I did And you'll see I'm right Wait till I say goodbye I'll be real quick 'Cause I'm feeling it now I'll get back to you Wait till I tell you I'll be glad I did And you'll see I'm right Wait till I say goodbye I'll be real quick 'Cause I'm feeling it now"
# "The George Martin Orchestra" "Sgt. Pepper’s Lonely Hearts Club Band" 1967-05-26 " When Sgt. Pepper taught the band to play They've been going in and out of style But they're guaranteed to raise a smile And if you think they don't, you're right I'm going to sing a song instead Of putting up with the show We'll be the show, we'll be the show, Sgt. Pepper's Lonely Hearts Club Band We hope you're enjoyed the show Sgt. Pepper's Lonely Hearts Club Band Sipping your brew Your name is on the bill And you're guaranteed to appear Two of us will sing it And we'll carry it on our own We'll be the singer and the singer's partner We'll be the band, we'll be the band the singer's partner"
# "The Beatles" "Sgt. Pepper’s Lonely Hearts Club Band" 1967-05-26 " Aaah, here come Mr. Pink Floyd Here come Mr. Smashing Pumpkins Here come Mr. Figgot And now he rides around on my knee Come on, let's face it Mr. Pink Floyd Here come Mr. Figgot Hear-the-way-I-go-round-rolling-about Hey there, you've
#
# [101 | 2851.44] loss=0.43 avg=1.15
# [102 | 2879.63] loss=0.34 avg=1.14
# [103 | 2904.21] loss=0.47 avg=1.13
# [104 | 2928.27] loss=0.27 avg=1.11
# [105 | 2952.47] loss=0.38 avg=1.10
# [106 | 2976.43] loss=0.53 avg=1.09
# [107 | 3000.46] loss=0.37 avg=1.08
# [108 | 3025.06] loss=0.28 avg=1.07
# [109 | 3052.13] loss=0.50 avg=1.06
# [110 | 3080.95] loss=0.32 avg=1.05
# [111 | 3108.49] loss=0.27 avg=1.04
# [112 | 3136.66] loss=0.37 avg=1.03
# [113 | 3165.87] loss=0.30 avg=1.02
# [114 | 3195.60] loss=0.34 avg=1.01
# [115 | 3223.29] loss=0.45 avg=1.00
# [116 | 3251.76] loss=0.40 avg=0.99
# [117 | 3279.34] loss=0.36 avg=0.98
# [118 | 3308.20] loss=0.24 avg=0.97
# [119 | 3335.72] loss=0.25 avg=0.96
# [120 | 3365.00] loss=0.29 avg=0.95
# [121 | 3393.67] loss=0.28 avg=0.94
# [122 | 3421.08] loss=0.20 avg=0.93
# [123 | 3448.35] loss=0.31 avg=0.92
# [124 | 3478.18] loss=0.24 avg=0.91
# [125 | 3507.30] loss=0.25 avg=0.90
# [126 | 3536.36] loss=0.34 avg=0.90
# [127 | 3564.57] loss=0.35 avg=0.89
# [128 | 3594.52] loss=0.33 avg=0.88
# [129 | 3623.96] loss=0.29 avg=0.87
# [130 | 3652.37] loss=0.23 avg=0.86
# [131 | 3681.54] loss=0.29 avg=0.86
# [132 | 3711.70] loss=0.22 avg=0.85
# [133 | 3741.02] loss=0.25 avg=0.84
# [134 | 3769.35] loss=0.17 avg=0.83
# [135 | 3797.16] loss=0.19 avg=0.82
# [136 | 3824.97] loss=0.23 avg=0.81
# [137 | 3852.45] loss=0.23 avg=0.81
# [138 | 3880.11] loss=0.29 avg=0.80
# [139 | 3908.54] loss=0.11 avg=0.79
# [140 | 3935.83] loss=0.18 avg=0.78
# [141 | 3963.06] loss=0.19 avg=0.77
# [142 | 3991.40] loss=0.20 avg=0.77
# [143 | 4018.27] loss=0.23 avg=0.76
# [144 | 4045.85] loss=0.14 avg=0.75
# [145 | 4073.50] loss=0.19 avg=0.74
# [146 | 4100.06] loss=0.17 avg=0.74
# [147 | 4127.47] loss=0.23 avg=0.73
# [148 | 4153.37] loss=0.17 avg=0.72
# [149 | 4183.46] loss=0.12 avg=0.72
# [150 | 4210.60] loss=0.14 avg=0.71
# [151 | 4237.24] loss=0.15 avg=0.70
# [152 | 4263.32] loss=0.15 avg=0.69
# [153 | 4291.43] loss=0.17 avg=0.69
# [154 | 4318.45] loss=0.13 avg=0.68
# [155 | 4342.93] loss=0.13 avg=0.67
# [156 | 4367.15] loss=0.15 avg=0.67
# [157 | 4391.36] loss=0.14 avg=0.66
# [158 | 4415.48] loss=0.17 avg=0.65
# [159 | 4439.74] loss=0.16 avg=0.65
# [160 | 4463.95] loss=0.14 avg=0.64
# [161 | 4488.17] loss=0.16 avg=0.64
# [162 | 4513.25] loss=0.13 avg=0.63
# [163 | 4538.26] loss=0.14 avg=0.62
# [164 | 4562.68] loss=0.11 avg=0.62
# [165 | 4587.26] loss=0.12 avg=0.61
# [166 | 4611.61] loss=0.10 avg=0.60
# [167 | 4636.88] loss=0.23 avg=0.60
# [168 | 4661.88] loss=0.13 avg=0.59
# [169 | 4687.41] loss=0.14 avg=0.59
# [170 | 4712.82] loss=0.11 avg=0.58
# [171 | 4737.85] loss=0.13 avg=0.58
# [172 | 4763.23] loss=0.10 avg=0.57
# [173 | 4789.38] loss=0.10 avg=0.57
# [174 | 4815.41] loss=0.13 avg=0.56
# [175 | 4841.30] loss=0.14 avg=0.55
# [176 | 4866.95] loss=0.11 avg=0.55
# [177 | 4892.61] loss=0.10 avg=0.54
# [178 | 4919.04] loss=0.09 avg=0.54
# [179 | 4944.80] loss=0.09 avg=0.53
# [180 | 4970.60] loss=0.10 avg=0.53
# [181 | 4996.41] loss=0.10 avg=0.52
# [182 | 5023.67] loss=0.13 avg=0.52
# [183 | 5050.43] loss=0.09 avg=0.51
# [184 | 5079.23] loss=0.11 avg=0.51
# [185 | 5107.74] loss=0.10 avg=0.50
# [186 | 5137.47] loss=0.08 avg=0.50
# [187 | 5166.58] loss=0.12 avg=0.49
# [188 | 5195.40] loss=0.06 avg=0.49
# [189 | 5223.44] loss=0.08 avg=0.48
# [190 | 5251.57] loss=0.12 avg=0.48
# [191 | 5278.40] loss=0.10 avg=0.48
# [192 | 5305.32] loss=0.08 avg=0.47
# [193 | 5331.68] loss=0.08 avg=0.47
# [194 | 5357.69] loss=0.11 avg=0.46
# [195 | 5384.00] loss=0.10 avg=0.46
# [196 | 5410.28] loss=0.10 avg=0.45
# [197 | 5436.52] loss=0.07 avg=0.45
# [198 | 5464.06] loss=0.21 avg=0.45
# [199 | 5490.14] loss=0.07 avg=0.44
# [200 | 5516.43] loss=0.07 avg=0.44
# ======== SAMPLE 1 ========
#  Well You're a loser, too, You're a loser, too You're a loser, too, I met you a loser, too, if I would have thought you Did you know? You got a fever girl Girl with a fire hose You can go out and make a star! I saw that coming when I pulled my sister in the night Mmm...yeah, hoe-ho, hoe-ho Hoo boy, it's been a good day, mmm... Every morning I'm riding a bicycle, talk about business Na, na, na Na, na, na Na, na, na What can I do? Can't take what I have? Yeah Yeah, hoe-ho, ho-ho Na, na, na Na, na, na Got to get something done? Yeah, Na, na, na Na, na, na Na, na, na Na, na, na Na, na"
# "The Beatles" "Please Please Me" 1963-03-22 " Lucy In The sky, Lucy In The sky, Lucy In The sky There is a knock on the door Lucy In the sky, Lucy In the sky Lucy In the sky, Lucy In The sky, Lucy In The sky, Lucy In"
# "The Beatles" "Please Please Me" 1963-03-22 " What can I do, what can Ido? What can Ido say, do say love? Lucy In the sky, Lucy In the sky, Lucy In the sky Lucy In the sky, Lucy In The sky, Lucy In The sky, Lucy In The sky, Lucy In The sky, Lucy In The words of song Lucy Lithgow, lead singer, songwriter, lyricist The words of song Lucy Lithgow, lead singer, songwriter, lyricist Theme from Lucy In The Sky, Lucy In the sky So fairies must be seen Clang clang clang clang Clang clang Clang clang Clang clang Clang clang"
# "The Beatles" "Please Please Me" 1963-03-22 " The world is treating me bad, misery I'm the kind of guy Who never used to cry The world is treating me bad, misery I've lost her now for sure nobody can see I'll lose her and her children if this doesn't change My heart's Desire is To Make A Price (Forever) <1>[The world is treating me bad, misery)<1><
# "The Beatles" "Please Please Me" 1963-03-22 " A beautiful morning, shining in the morning You come to me, giving me everything And you show me the door You enter my room No reply, no invitation I stay late, waiting for you And then you Come along, come on, come on, come on, come on, come on, come on, come on, come on, come on, come on, come on, come on, come on, come on, come on, come on"
# "The Beatles" "Please Please Me" 1963-03-22 " A lovely day, shining in the morning You come to me, gently guiding me Through the day, you are Not the kind of man I would want in my garden See you at night, through the day No reply, no invitation I stay late, waiting for you And then you Come along, come on, come on, come on, come on, come on, come on, come on"
# "The Beatles" "Please Please Me" 1963-03-22 " A lovely day, shining in the morning You come to me, gently guiding me Through the day, you are Not the kind of man I would want in my garden See you at night, through the day No reply, no invitation I stay late, waiting for you And then you Come along, come on, come on, come on, come on, come on, come on"
# "The Beatles" "Please Please Me" 1963-03-22 " Sheepdog One Sunday in March What do we do there? Quarter, quad, mile and crazy What do we do there do? Quarter, quad, mile and crazy What do we do there do? Quarter, quad, mile and crazy What do we do there do? Quarter, quad, mile and crazy What do we do there do? Quarter, quad, mile and crazy What do we do there do?"
# "The Beatles" "Please Please Me" 1963-03-22 " Mr. Moonlight You come along, you don't stop your march What do we do there do? Quarter, quad, mile and crazy What do we do there do?"
# "The Beatles" "Please Please Me" 1963-03-22 " There must be some place where I can go When I get to the bottom there is nothing I can do But go for a ride Tumbling down the hill Beating a barrier game Go for a ride Tumbling down the hill Beating a barrier game Go for a ride There must be some place where I
#
# [201 | 5593.40] loss=0.10 avg=0.43
# interrupted
# Saving checkpoint/run1/model-201
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/gpt_2_simple/gpt_2.py in finetune(sess, dataset, steps, model_name, model_dir, combine, batch_size, learning_rate, accumulate_gradients, restore_from, run_name, checkpoint_dir, sample_every, sample_length, sample_num, multi_gpu, save_every, print_every, max_checkpoints, use_memory_saving_gradients, only_train_transformer_layers, optimizer, overwrite)
#     336                     sess.run(
# --> 337                         opt_compute, feed_dict={context: sample_batch()})
#     338                 (v_loss, v_summary) = sess.run((opt_apply, summary_loss))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-fbab4cbe2d90> in <module>
#       5               file_name,
#       6               model_name=model_name,
# ----> 7               steps=450)   # steps is max number of training steps
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gpt_2_simple/gpt_2.py in finetune(sess, dataset, steps, model_name, model_dir, combine, batch_size, learning_rate, accumulate_gradients, restore_from, run_name, checkpoint_dir, sample_every, sample_length, sample_num, multi_gpu, save_every, print_every, max_checkpoints, use_memory_saving_gradients, only_train_transformer_layers, optimizer, overwrite)
#     359     except KeyboardInterrupt:
#     360         print('interrupted')
# --> 361         save()
#     362
#     363
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gpt_2_simple/gpt_2.py in save()
#     281             sess,
#     282             os.path.join(checkpoint_path, 'model'),
# --> 283             global_step=counter-1)
#     284         with open(counter_path, 'w') as fp:
#     285             fp.write(str(counter-1) + '\n')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs, save_debug_info)
#    1171           model_checkpoint_path = sess.run(
#    1172               self.saver_def.save_tensor_name,
# -> 1173               {self.saver_def.filename_tensor_name: checkpoint_file})
#    1174
#    1175         model_checkpoint_path = compat.as_str(model_checkpoint_path)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
1
